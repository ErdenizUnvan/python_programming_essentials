# %%
#print, input, f'', \n, end =' ', \r, 
#def
#definition
def definition(a,b):
    return a * b

# %%
sayi1 = int(input('1.sayiyi yaziniz: '))
sayi2 = int(input('2.sayiyi yaziniz: '))
print(f'{sayi1} X {sayi2} = {definition(sayi1,sayi2)}')
# Out:
# 1.sayiyi yaziniz: 123456789
# 2.sayiyi yaziniz: 987654321
# 123456789 X 987654321 = 121932631112635269

# %%
#Python ile guzel bir hesap makinesi yapalim

def topla(a,b):
    return a + b

def cikar(a,b):
    return a - b  

def carpma(a,b):
    return a * b  

def bolme(a,b):
    return a / b

menu = """

Python ile Hesap Makinemize Hosgeldiniz:

Toplama icin : 1
Cikarma icin : 2
Carpma icin  : 3
Bolme icin   : 4
Cikis        : 5

"""

print(menu)

while True:
    secim = input('Bir secim yapin: 1/2/3/4/5: ')
    
    if secim == '5':
        print('Cikis')
        break
    elif secim == '1':
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} + {sayi2} = {topla(sayi1,sayi2)}')
        
    elif secim == '2':
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} - {sayi2} = {cikar(sayi1,sayi2)}')
        
    elif secim == '3':
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} X {sayi2} = {carpma(sayi1,sayi2)}')
        
    elif secim == '4':
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} / {sayi2} = {bolme(sayi1,sayi2)}')
        
    else:
        print('Yanlis bir secim yapitiniz.\n',menu)
# Out:
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5: 1
# 1.sayiyi yaziniz: 1
# 2.sayiyi yaziniz: 123
# 1 + 123 = 124
# Bir secim yapin: 1/2/3/4/5: 2
# 1.sayiyi yaziniz: 123
# 2.sayiyi yaziniz: 32
# 123 - 32 = 91
# Bir secim yapin: 1/2/3/4/5: 3
# 1.sayiyi yaziniz: 123
# 2.sayiyi yaziniz: 321
# 123 X 321 = 39483
# Bir secim yapin: 1/2/3/4/5: 4
# 1.sayiyi yaziniz: 8
# 2.sayiyi yaziniz: 4
# 8 / 4 = 2.0
# Bir secim yapin: 1/2/3/4/5:  1
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5:
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5:   1
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5:  #
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5: #
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5: abc
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5: a1
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5:  #a1
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : 1
# Cikarma icin : 2
# Carpma icin  : 3
# Bolme icin   : 4
# Cikis        : 5
#
#
# Bir secim yapin: 1/2/3/4/5: 5
# Cikis

# %%
#Python ile guzel bir hesap makinesi yapalim

def topla(a,b):
    return a + b

def cikar(a,b):
    return a - b  

def carpma(a,b):
    return a * b  

def bolme(a,b):
    return a / b

menu = """

Python ile Hesap Makinemize Hosgeldiniz:

Toplama icin : +
Cikarma icin : -
Carpma icin  : X
Bolme icin   : /
Cikis        : ESC

"""

print(menu)

while True:
    secim = input('Bir secim yapin: +,-,X,/,ESC: ')
    
    if secim.upper() == 'ESC':
        print('Cikis')
        break
    elif secim == '+':
        print('Toplama Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} + {sayi2} = {topla(sayi1,sayi2)}')
        
    elif secim == '-':
        print('Cikarma Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} - {sayi2} = {cikar(sayi1,sayi2)}')
        
    elif secim == 'X':
        print('Carpma Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} X {sayi2} = {carpma(sayi1,sayi2)}')
        
    elif secim == '/':
        print('Bolme Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} / {sayi2} = {bolme(sayi1,sayi2)}')
        
    else:
        print('Yanlis bir secim yapitiniz.\n',menu)
# Out:
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : +
# Cikarma icin : -
# Carpma icin  : X
# Bolme icin   : /
# Cikis        : ESC
#
#
# Bir secim yapin: +,-,X,/,ESC: +
# Toplama Islemi
# 1.sayiyi yaziniz: 1
# 2.sayiyi yaziniz: 123456
# 1 + 123456 = 123457
# Bir secim yapin: +,-,X,/,ESC: -
# Cikarma Islemi
# 1.sayiyi yaziniz: 987
# 2.sayiyi yaziniz: 123
# 987 - 123 = 864
# Bir secim yapin: +,-,X,/,ESC: X
# Carpma Islemi
# 1.sayiyi yaziniz: 345
# 2.sayiyi yaziniz: 654
# 345 X 654 = 225630
# Bir secim yapin: +,-,X,/,ESC: /
# Bolme Islemi
# 1.sayiyi yaziniz: 68
# 2.sayiyi yaziniz: 2
# 68 / 2 = 34.0
# Bir secim yapin: +,-,X,/,ESC:  +
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : +
# Cikarma icin : -
# Carpma icin  : X
# Bolme icin   : /
# Cikis        : ESC
#
#
# Bir secim yapin: +,-,X,/,ESC:  -
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : +
# Cikarma icin : -
# Carpma icin  : X
# Bolme icin   : /
# Cikis        : ESC
#
#
# Bir secim yapin: +,-,X,/,ESC: #X
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : +
# Cikarma icin : -
# Carpma icin  : X
# Bolme icin   : /
# Cikis        : ESC
#
#
# Bir secim yapin: +,-,X,/,ESC: a/
# Yanlis bir secim yapitiniz.
#
#
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : +
# Cikarma icin : -
# Carpma icin  : X
# Bolme icin   : /
# Cikis        : ESC
#
#
# Bir secim yapin: +,-,X,/,ESC: EsC
# Cikis

# %%
#Python ile guzel bir hesap makinesi yapalim

def topla(a,b):
    return a + b

def cikar(a,b):
    return a - b  

def carpma(a,b):
    return a * b  

def bolme(a,b):
    return a / b

menu = """

Python ile Hesap Makinemize Hosgeldiniz:

Toplama icin : +
Cikarma icin : -
Carpma icin  : X
Bolme icin   : /
Cikis        : ESC

"""

anahtar = 1 

print(menu)

while anahtar == 1:
    secim = input('Bir secim yapin: +,-,X,/,ESC: ')
    
    if secim.upper() == 'ESC':
        print('Cikis')
        anahtar = 2
        
    elif secim == '+':
        print('Toplama Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} + {sayi2} = {topla(sayi1,sayi2)}')
        
    elif secim == '-':
        print('Cikarma Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} - {sayi2} = {cikar(sayi1,sayi2)}')
        
    elif secim == 'X':
        print('Carpma Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} X {sayi2} = {carpma(sayi1,sayi2)}')
        
    elif secim == '/':
        print('Bolme Islemi')
        sayi1 = int(input('1.sayiyi yaziniz: '))
        sayi2 = int(input('2.sayiyi yaziniz: '))
        print(f'{sayi1} / {sayi2} = {bolme(sayi1,sayi2)}')
        
    else:
        print('Yanlis bir secim yapitiniz.\n',menu)
# Out:
# Python ile Hesap Makinemize Hosgeldiniz:
#
# Toplama icin : +
# Cikarma icin : -
# Carpma icin  : X
# Bolme icin   : /
# Cikis        : ESC
#
#
# Bir secim yapin: +,-,X,/,ESC: ESC
# Cikis
